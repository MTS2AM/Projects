# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#years = list(range(2022,2017,-1))

# %%
years = 2022
year = 2022

# %%
all_matches = []

# %%
standing_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
import time
for n in range(0,1) :
    data = requests.get(standing_url)
    soup = BeautifulSoup(data.text)
    standing_table = soup.select('table.stats_table')[0]
    
    links = [l.get("href") for l in standing_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f'https://fbref.com{l}' for l in links]
    
    previous_season = soup.select('a.prev')[0].get('href')
    standing_url = f'https://fbref.com{previous_season}'
    
    for team_url in team_urls :
        team_name = team_url.split('/')[-1].replace('-Stats','').replace('-',' ')
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match ="Scores & Fixtures")[0]
        
        
        
        soup = BeautifulSoup(data.text)
        time.sleep(15)
        links = [l.get('href') for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f'https://fbref.com{links[0]}')
       
        time.sleep(15)
        
        shooting = pd.read_html(data.text, match ='Shooting')[0]
        shooting.columns = shooting.columns.droplevel()
        
        try: 
            team_data = matches.merge(shooting[['Date','Sh','SoT','Dist','FK','PK','PKatt']], on='Date')
        except ValueError:
            pass
        team_data = team_data[team_data['Comp'] == 'Premier League']
        team_data['Season'] = year
        team_data['Team'] = team_name
        all_matches.append(team_data)
        time.sleep(15)

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
len(match_df)
# Out:
# 212

# %%
match_df
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2   2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3   2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4   2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 7   2022-09-16  20:00  Premier League   Matchweek 8  Fri  Home      L  2.0
# 8   2022-10-03  20:00  Premier League   Matchweek 9  Mon  Away      L  0.0
# 9   2022-10-10  20:00  Premier League  Matchweek 10  Mon  Home      D  1.0
# 10  2022-10-15  15:00  Premier League  Matchweek 11  Sat  Away      L  0.0
# 11  2022-10-18  19:30  Premier League  Matchweek 12  Tue  Away      D  0.0
#
#      ga        opponent  ...  match report  notes    sh  sot  dist   fk pk  \
# 0   0.0  Crystal Palace  ...  Match Report    NaN  10.0  2.0  15.0  1.0  0
# 1   2.0  Leicester City  ...  Match Report    NaN  19.0  7.0  12.6  0.0  0
# 2   0.0     Bournemouth  ...  Match Report    NaN  14.0  6.0  14.6  0.0  0
# 3   1.0          Fulham  ...  Match Report    NaN  23.0  8.0  16.6  1.0  0
# 4   1.0     Aston Villa  ...  Match Report    NaN  22.0  8.0  15.3  1.0  0
# ..  ...             ...  ...           ...    ...   ...  ...   ...  ... ..
# 7   3.0          Fulham  ...  Match Report    NaN  11.0  3.0  15.8  1.0  0
# 8   4.0  Leicester City  ...  Match Report    NaN  10.0  3.0  15.0  0.0  0
# 9   1.0     Aston Villa  ...  Match Report    NaN   6.0  3.0  18.2  0.0  0
# 10  1.0          Wolves  ...  Match Report    NaN   9.0  1.0  19.1  1.0  0
# 11  0.0        Brighton  ...  Match Report    NaN   3.0  0.0  10.9  0.0  0
#
#    pkatt season               team
# 0      0   2022            Arsenal
# 1      0   2022            Arsenal
# 2      0   2022            Arsenal
# 3      0   2022            Arsenal
# 4      0   2022            Arsenal
# ..   ...    ...                ...
# 7      0   2022  Nottingham Forest
# 8      0   2022  Nottingham Forest
# 9      0   2022  Nottingham Forest
# 10     1   2022  Nottingham Forest
# 11     0   2022  Nottingham Forest
#
# [212 rows x 27 columns]

# %%
match_df[match_df['team'] == 'Manchester City']
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3   2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D  3.0
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5   2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# 6   2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9   2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 10  2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W  6.0
# 12  2022-10-08  15:00  Premier League  Matchweek 10  Sat  Home      W  4.0
# 14  2022-10-16  16:30  Premier League  Matchweek 11  Sun  Away      L  0.0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk pk  \
# 1   0.0         West Ham  ...  Match Report    NaN  13.0   1.0  18.2  1.0  1
# 2   0.0      Bournemouth  ...  Match Report    NaN  20.0   7.0  15.6  0.0  0
# 3   3.0    Newcastle Utd  ...  Match Report    NaN  22.0  10.0  15.1  1.0  0
# 4   2.0   Crystal Palace  ...  Match Report    NaN  18.0   5.0  13.1  0.0  0
# 5   0.0  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.1  0.0  0
# 6   1.0      Aston Villa  ...  Match Report    NaN  13.0   4.0  15.7  1.0  0
# 9   0.0           Wolves  ...  Match Report    NaN  15.0   7.0  18.8  0.0  0
# 10  3.0   Manchester Utd  ...  Match Report    NaN  22.0   9.0  13.5  1.0  0
# 12  0.0      Southampton  ...  Match Report    NaN  21.0   8.0  14.0  0.0  0
# 14  1.0        Liverpool  ...  Match Report    NaN  16.0   6.0  17.3  0.0  0
#
#    pkatt season             team
# 1      1   2022  Manchester City
# 2      0   2022  Manchester City
# 3      0   2022  Manchester City
# 4      0   2022  Manchester City
# 5      0   2022  Manchester City
# 6      0   2022  Manchester City
# 9      0   2022  Manchester City
# 10     0   2022  Manchester City
# 12     0   2022  Manchester City
# 14     0   2022  Manchester City
#
# [10 rows x 27 columns]

# %%
match_df.to_csv('updated.csv')
