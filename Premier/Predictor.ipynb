# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import swifter

# %%
df = pd.read_csv('First_try.csv',header=0,index_col=0)

# %%
df2 = pd.read_csv('updated.csv',header=0,index_col=0)

# %%
len(df)
# Out:
# 3800

# %%
df2[df2['team'] == 'Liverpool']
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2022-08-06  12:30  Premier League   Matchweek 1  Sat  Away      D  2.0
# 2   2022-08-15  20:00  Premier League   Matchweek 2  Mon  Home      D  1.0
# 3   2022-08-22  20:00  Premier League   Matchweek 3  Mon  Away      L  1.0
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  9.0
# 5   2022-08-31  20:00  Premier League   Matchweek 5  Wed  Home      W  2.0
# 6   2022-09-03  12:30  Premier League   Matchweek 6  Sat  Away      D  0.0
# 9   2022-10-01  15:00  Premier League   Matchweek 9  Sat  Home      D  3.0
# 11  2022-10-09  16:30  Premier League  Matchweek 10  Sun  Away      L  2.0
# 13  2022-10-16  16:30  Premier League  Matchweek 11  Sun  Home      W  1.0
# 14  2022-10-19  19:30  Premier League  Matchweek 12  Wed  Home      W  1.0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk pk  \
# ...

# %% [markdown]
# ### This week matches

# %%
df_topred = [['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Home','W',0,0,'Liverpool',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,"Nott'ham Forest"],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Home','W',0,0,'Crystal Palace',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,"Everton"],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Home','W',0,0,'Brighton',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,"Manchester City"],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Home','W',0,0,"Manchester Utd",0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Chelsea'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Home','W',0,0,'Leicester City',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Wolves'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Home','W',0,0,"Brentford",0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Aston Villa'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Home','W',0,0,'Arsenal',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Southampton'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Home','W',0,0,'Fulham',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Leeds United'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Home','W',0,0,'Newcastle Utd',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Tottenham'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Home','W',0,0,"Bournemouth",0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,"West Ham"],

 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Away','W',0,0,"Nott'ham Forest",0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Liverpool'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Away','W',0,0,"Everton",0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Crystal Palace'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Away','W',0,0,"Manchester City",0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,"Brighton"],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Away','W',0,0,'Chelsea',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,"Manchester Utd"],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Away','W',0,0,'Wolves',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Leicester City'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Away','W',0,0,'Aston Villa',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,"Brentford"],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Away','W',0,0,'Southampton',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Arsenal'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Away','W',0,0,'Leeds United',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Fulham'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Away','W',0,0,'Tottenham',0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,'Newcastle Utd'],
 ['2022-10-22','12:30','Premier League','Matchweek 13','Sat','Away','W',0,0,"West Ham",0,0,0,0,'İlkay Gündoğan','4-3-3','Martin Atkinson','Match Report',np.nan,0,0,0,0,0,0,2023,"Bournemouth"]]

# %%
df_updater = pd.DataFrame(df_topred, columns = df.columns)

# %%
df_updater
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 0   2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W   0   0
# 1   2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W   0   0
# 2   2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W   0   0
# 3   2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W   0   0
# 4   2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W   0   0
# 5   2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W   0   0
# 6   2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W   0   0
# 7   2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W   0   0
# 8   2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W   0   0
# 9   2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W   0   0
# 10  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W   0   0
# ...

# %%
df_final = pd.concat([df,df2,df_updater])

# %%
df_final
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2   2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3   2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4   2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 15  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W  0.0
# 16  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W  0.0
# 17  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W  0.0
# 18  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W  0.0
# 19  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W  0.0
#
# ...

# %%
df_final[df_final['date'] > '09-02-2022']
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2   2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3   2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4   2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 15  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W  0.0
# 16  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W  0.0
# 17  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W  0.0
# 18  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W  0.0
# 19  2022-10-22  12:30  Premier League  Matchweek 13  Sat  Away      W  0.0
#
# ...

# %%
df_final['date'] = pd.to_datetime(df_final['date'])

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4032 entries, 1 to 19
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          4032 non-null   datetime64[ns]
#  1   time          4032 non-null   object
#  2   comp          4032 non-null   object
#  3   round         4032 non-null   object
#  4   day           4032 non-null   object
#  5   venue         4032 non-null   object
#  6   result        4032 non-null   object
#  7   gf            4032 non-null   float64
#  8   ga            4032 non-null   float64
#  9   opponent      4032 non-null   object
#  10  xg            4030 non-null   float64
#  11  xga           4030 non-null   float64
#  12  poss          4032 non-null   float64
#  13  attendance    3152 non-null   float64
#  14  captain       4032 non-null   object
#  15  formation     4032 non-null   object
#  16  referee       4032 non-null   object
# ...

# %%
df_final.head()
# Out:
#         date venue team_name      opponent  poss_rolling  gf_rolling  \
# 5 2017-09-25  Home   Arsenal     West Brom          60.4         1.4
# 6 2017-10-01  Home   Arsenal      Brighton          60.4         1.0
# 7 2017-10-14  Away   Arsenal       Watford          57.8         1.4
# 8 2017-10-22  Away   Arsenal       Everton          58.4         1.6
# 9 2017-10-28  Home   Arsenal  Swansea City          60.2         2.0
#
#    ga_rolling  sh_rolling  sot_rolling  fk_rolling  ...  opp  team  \
# 5         1.6        16.4          5.6         0.2  ...   26     0
# 6         1.0        14.0          4.6         0.8  ...    4     0
# 7         0.8        15.4          4.8         1.2  ...   25     0
# 8         0.4        15.6          6.0         1.2  ...    9     0
# 9         0.8        17.8          7.0         1.4  ...   23     0
#
#    opponent_poss_rolling  opponent_gf_rolling  opponent_ga_rolling  \
# 5                   38.6                  0.8                  0.8
# ...

# %%
df_final.iloc[18]
# Out:
# date            2021-12-26 00:00:00
# time                          15:00
# comp                 Premier League
# round                  Matchweek 19
# day                             Sun
# venue                          Home
# result                            W
# gf                              6.0
# ga                              3.0
# opponent             Leicester City
# xg                              3.4
# xga                             2.4
# poss                           72.0
# attendance                  53226.0
# captain                 Fernandinho
# formation                     4-3-3
# referee              Chris Kavanagh
# match report           Match Report
# notes                           NaN
# sh                             15.0
# sot                             6.0
# dist                           16.6
# fk                              1.0
# pk                              2.0
# pkatt                           2.0
# season                         2022
# ...

# %%
df_final.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team'],
#       dtype='object')

# %%
a = pd.Series(df_final['opponent'].unique())

# %%
b = pd.Series(df_final['team'].unique())

# %%
a.sort_values()
# Out:
# 2             Arsenal
# 13        Aston Villa
# 23        Bournemouth
# 18          Brentford
# 8            Brighton
# 7             Burnley
# 25       Cardiff City
# 5             Chelsea
# 9      Crystal Palace
# 11            Everton
# 21             Fulham
# 24       Huddersfield
# 16       Leeds United
# 3      Leicester City
# 6           Liverpool
# 19    Manchester City
# 10     Manchester Utd
# 17      Newcastle Utd
# 1        Norwich City
# 28    Nott'ham Forest
# 20      Sheffield Utd
# 4         Southampton
# 26         Stoke City
# 27       Swansea City
# 0           Tottenham
# 14            Watford
# 22          West Brom
# 12           West Ham
# 15             Wolves
# dtype: object

# %%
b.sort_values()
# Out:
# 4                      Arsenal
# 13                 Aston Villa
# 23                 Bournemouth
# 12                   Brentford
# 33                    Brighton
# 8     Brighton and Hove Albion
# 17                     Burnley
# 24                Cardiff City
# 2                      Chelsea
# 11              Crystal Palace
# 15                     Everton
# 20                      Fulham
# 25           Huddersfield Town
# 16                Leeds United
# 7               Leicester City
# 1                    Liverpool
# 0              Manchester City
# 5            Manchester United
# 34              Manchester Utd
# 10            Newcastle United
# 35               Newcastle Utd
# 19                Norwich City
# 29             Nott'ham Forest
# 28           Nottingham Forest
# 22            Sheffield United
# 14                 Southampton
# 27                  Stoke City
# 26                Swansea City
# 31                   Tottenham
# 3            Tottenham Hotspur
# ...

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion" : "Brighton",
    "Huddersfield Town" : "Huddersfield",
    "Manchester United" : "Manchester Utd",
    "Newcastle United" : "Newcastle Utd",
    "Nottingham Forest" : "Nott'ham Forest",
    "Sheffield United" : "Sheffield Utd",
    "Tottenham Hotspur" : "Tottenham",
    "West Bromwich Albion": "West Brom",
    "West Ham United" : "West Ham",
    "Wolverhampton Wanderers" : "Wolves"}

# %%
mapping = MissingDict(**map_values)

# %%
df_final['team_name'] = df_final['team'].map(mapping)

# %%
df_final.index = range(df_final.shape[0])

# %%
df_final.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team', 'team_name'],
#       dtype='object')

# %%
def rolling_averages( group, cols, new_cols) :
    group = group.sort_values('date')
    rolling_stats = group[cols].rolling(5, closed = 'left').mean()
    group[new_cols] = rolling_stats
    #group = group.dropna(subset = new_cols)
    return group

# %%
cols = ['poss','gf','ga','sh','sot','fk','pk','pkatt']
new_cols = [f'{c}_rolling' for c in cols]

# %%
new_cols
# Out:
# ['poss_rolling',
#  'gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
df_ml = df_final.groupby('team_name').apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
df_ml = df_ml.droplevel('team_name')

# %%
df_ml
# Out:
#            date   time            comp         round  day venue result   gf  \
# 3230 2017-08-11  19:45  Premier League   Matchweek 1  Fri  Home      W  4.0
# 3231 2017-08-19  17:30  Premier League   Matchweek 2  Sat  Away      L  0.0
# 3232 2017-08-27  16:00  Premier League   Matchweek 3  Sun  Away      L  0.0
# 3233 2017-09-09  15:00  Premier League   Matchweek 4  Sat  Home      W  3.0
# 3234 2017-09-17  13:30  Premier League   Matchweek 5  Sun  Away      D  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 3986 2022-10-01  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# 3987 2022-10-08  15:00  Premier League  Matchweek 10  Sat  Away      L  0.0
# 3988 2022-10-15  15:00  Premier League  Matchweek 11  Sat  Home      W  1.0
# 3989 2022-10-18  20:15  Premier League  Matchweek 12  Tue  Away      L  1.0
# 4016 2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W  0.0
#
# ...

# %%
df_ml.index = range(df_ml.shape[0])

# %%
#df_ml = df_ml.drop('Unnamed: 0', axis=1)

# %%
df_ml
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2017-08-11  19:45  Premier League   Matchweek 1  Fri  Home      W  4.0
# 1    2017-08-19  17:30  Premier League   Matchweek 2  Sat  Away      L  0.0
# 2    2017-08-27  16:00  Premier League   Matchweek 3  Sun  Away      L  0.0
# 3    2017-09-09  15:00  Premier League   Matchweek 4  Sat  Home      W  3.0
# 4    2017-09-17  13:30  Premier League   Matchweek 5  Sun  Away      D  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 4027 2022-10-01  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# 4028 2022-10-08  15:00  Premier League  Matchweek 10  Sat  Away      L  0.0
# 4029 2022-10-15  15:00  Premier League  Matchweek 11  Sat  Home      W  1.0
# 4030 2022-10-18  20:15  Premier League  Matchweek 12  Tue  Away      L  1.0
# 4031 2022-10-22  12:30  Premier League  Matchweek 13  Sat  Home      W  0.0
#
# ...

# %%
df_ml.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team', 'team_name', 'poss_rolling', 'gf_rolling',
#        'ga_rolling', 'sh_rolling', 'sot_rolling', 'fk_rolling', 'pk_rolling',
#        'pkatt_rolling'],
#       dtype='object')

# %%
df_finalml = df_ml[['date','venue','team_name','opponent','poss_rolling', 'gf_rolling',
       'ga_rolling', 'sh_rolling', 'sot_rolling', 'fk_rolling', 'pk_rolling',
       'pkatt_rolling','result']]

# %%
df_finalml
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 0    2017-08-11  Home   Arsenal   Leicester City           NaN         NaN
# 1    2017-08-19  Away   Arsenal       Stoke City           NaN         NaN
# 2    2017-08-27  Away   Arsenal        Liverpool           NaN         NaN
# 3    2017-09-09  Home   Arsenal      Bournemouth           NaN         NaN
# 4    2017-09-17  Away   Arsenal          Chelsea           NaN         NaN
# ...         ...   ...       ...              ...           ...         ...
# 4027 2022-10-01  Away    Wolves         West Ham          48.6         0.4
# 4028 2022-10-08  Away    Wolves          Chelsea          51.0         0.4
# 4029 2022-10-15  Home    Wolves  Nott'ham Forest          52.0         0.2
# 4030 2022-10-18  Away    Wolves   Crystal Palace          50.6         0.4
# 4031 2022-10-22  Home    Wolves   Leicester City          50.2         0.4
#
#       ga_rolling  sh_rolling  sot_rolling  fk_rolling  pk_rolling  \
# ...

# %%
df_finalml['result'] = df_finalml['result'].map({'W' :0, 'L' :1, 'D' :2})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\1153393559.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_finalml['result'] = df_finalml['result'].map({'W' :0, 'L' :1, 'D' :2})

# %%
df_finalml
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 0    2017-08-11  Home   Arsenal   Leicester City           NaN         NaN
# 1    2017-08-19  Away   Arsenal       Stoke City           NaN         NaN
# 2    2017-08-27  Away   Arsenal        Liverpool           NaN         NaN
# 3    2017-09-09  Home   Arsenal      Bournemouth           NaN         NaN
# 4    2017-09-17  Away   Arsenal          Chelsea           NaN         NaN
# ...         ...   ...       ...              ...           ...         ...
# 4027 2022-10-01  Away    Wolves         West Ham          48.6         0.4
# 4028 2022-10-08  Away    Wolves          Chelsea          51.0         0.4
# 4029 2022-10-15  Home    Wolves  Nott'ham Forest          52.0         0.2
# 4030 2022-10-18  Away    Wolves   Crystal Palace          50.6         0.4
# 4031 2022-10-22  Home    Wolves   Leicester City          50.2         0.4
#
#       ga_rolling  sh_rolling  sot_rolling  fk_rolling  pk_rolling  \
# ...

# %%
df_man = df_finalml[df_finalml['team_name'] == 'Fulham']

# %%
df_man[df_man['opponent'] == 'Leeds United']
# Out:
#            date venue team_name      opponent  poss_rolling  gf_rolling  \
# 1575 2020-09-19  Away    Fulham  Leeds United          58.8         0.4
# 1603 2021-03-19  Home    Fulham  Leeds United          52.6         0.4
# 1623 2022-10-22  Away    Fulham  Leeds United          54.0         2.0
#
#       ga_rolling  sh_rolling  sot_rolling  fk_rolling  pk_rolling  \
# 1575         1.6         9.8          2.4         0.0         0.2
# 1603         0.8        11.6          3.4         0.2         0.0
# 1623         2.2        12.4          3.8         0.8         0.4
#
#       pkatt_rolling  result  local  opp  team
# 1575            0.2       1      0   12    10
# 1603            0.0       1      1   12    10
# 1623            0.4       0      0   12    10

# %%
df_finalml["opponent"].unique()
# Out:
# array(['Leicester City', 'Stoke City', 'Liverpool', 'Bournemouth',
#        'Chelsea', 'West Brom', 'Brighton', 'Watford', 'Everton',
#        'Swansea City', 'Manchester City', 'Tottenham', 'Burnley',
#        'Huddersfield', 'Manchester Utd', 'Southampton', 'West Ham',
#        'Newcastle Utd', 'Crystal Palace', 'Cardiff City', 'Fulham',
#        'Wolves', 'Aston Villa', 'Sheffield Utd', 'Norwich City',
#        'Leeds United', 'Brentford', 'Arsenal', "Nott'ham Forest"],
#       dtype=object)

# %%
df_finalml["team_name"].unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton',
#        'Burnley', 'Cardiff City', 'Chelsea', 'Crystal Palace', 'Everton',
#        'Fulham', 'Huddersfield', 'Leeds United', 'Leicester City',
#        'Liverpool', 'Manchester City', 'Manchester Utd', 'Newcastle Utd',
#        'Norwich City', "Nott'ham Forest", 'Sheffield Utd', 'Southampton',
#        'Stoke City', 'Swansea City', 'Tottenham', 'Watford', 'West Brom',
#        'West Ham', 'Wolves'], dtype=object)

# %%
df_finalml["local"] = df_finalml["venue"].astype("category").cat.codes
df_finalml["opp"] = df_finalml["opponent"].astype("category").cat.codes
df_finalml["team"] = df_finalml["team_name"].astype("category").cat.codes
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\1894088467.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_finalml["local"] = df_finalml["venue"].astype("category").cat.codes
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\1894088467.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_finalml["opp"] = df_finalml["opponent"].astype("category").cat.codes
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\1894088467.py:3: SettingWithCopyWarning:
# ...

# %%
df_finalml.columns
# Out:
# Index(['date', 'venue', 'team_name', 'opponent', 'poss_rolling', 'gf_rolling',
#        'ga_rolling', 'sh_rolling', 'sot_rolling', 'fk_rolling', 'pk_rolling',
#        'pkatt_rolling', 'result', 'local', 'opp', 'team'],
#       dtype='object')

# %%
new_cols
# Out:
# ['poss_rolling',
#  'gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
opp_cols = [f'opponent_{c}' for c in new_cols]

# %%
opp_cols
# Out:
# ['opponent_poss_rolling',
#  'opponent_gf_rolling',
#  'opponent_ga_rolling',
#  'opponent_sh_rolling',
#  'opponent_sot_rolling',
#  'opponent_fk_rolling',
#  'opponent_pk_rolling',
#  'opponent_pkatt_rolling']

# %%
#pd.set_option('chained_assignment',None)

# %%
#opponent_stats ('opponent_poss_rolling','poss_rolling')

# %%
#df_newtrial = df_trial.apply(opponent_stats ('opponent_poss_rolling','poss_rolling'))

# %%
#for n in len(df_trial)
#df_trial[opp_cols] = np.nan
#df_trial
#df_trial.at[ind2,opp_cols] = df_finalml[new_cols].iloc[ind].values.astype(float)

# %%
len(df_finalml['date'].unique())
# Out:
# 618

# %%
len(df_finalml['opp'].unique())
# Out:
# 29

# %%
df_trial = df_finalml.copy()

# %%
def opponent_stats(opp_cols,new_cols):

    for n in range(0,30):
        df_trol = df_finalml[df_finalml['team'] == n]
        df_trol = df_trol.sort_values(['date'])
        a = df_trol['opp']
        b = df_trol['date']
        j = 0
        q = 0

        while j < len(a) :
            ind = df_finalml[(df_finalml['date'] == b.tolist()[j]) & (df_finalml['team'] == a.tolist()[j])].index.values.astype(int)[0]
            ind2 = df_finalml[(df_finalml['date'] == b.tolist()[j]) & (df_finalml['opp'] == a.tolist()[j])].index.values.astype(int)[0]
            while q < len(opp_cols) : 
                df_trial.at[ind2,opp_cols[q]]= df_finalml[new_cols[q]].iloc[ind].astype(float)
                q = q + 1
            j = j + 1
            q = 0

# %%
df_trial[df_trial['team_name'] == 'Fulham']
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 1536 2018-08-11  Home    Fulham   Crystal Palace           NaN         NaN
# 1537 2018-08-18  Away    Fulham        Tottenham           NaN         NaN
# 1538 2018-08-26  Home    Fulham          Burnley           NaN         NaN
# 1539 2018-09-01  Away    Fulham         Brighton           NaN         NaN
# 1540 2018-09-15  Away    Fulham  Manchester City           NaN         NaN
# ...         ...   ...       ...              ...           ...         ...
# 1619 2022-10-01  Home    Fulham    Newcastle Utd          43.8         2.0
# 1620 2022-10-09  Away    Fulham         West Ham          41.6         1.6
# 1621 2022-10-15  Home    Fulham      Bournemouth          45.6         1.6
# 1622 2022-10-20  Home    Fulham      Aston Villa          51.4         1.6
# 1623 2022-10-22  Away    Fulham     Leeds United          54.0         2.0
#
# ...

# %%
opponent_stats(opp_cols,new_cols)

# %%
a = df_finalml['opp']
b = df_finalml['date']

# %%
a
# Out:
# 0       13
# 1       22
# 2       14
# 3        2
# 4        7
#         ..
# 4027    27
# 4028     7
# 4029    19
# 4030     8
# 4031    13
# Name: opp, Length: 4032, dtype: int8

# %%
b
# Out:
# 0      2017-08-11
# 1      2017-08-19
# 2      2017-08-27
# 3      2017-09-09
# 4      2017-09-17
#           ...
# 4027   2022-10-01
# 4028   2022-10-08
# 4029   2022-10-15
# 4030   2022-10-18
# 4031   2022-10-22
# Name: date, Length: 4032, dtype: datetime64[ns]

# %%
df_trial[df_trial['date'] == '2017-08-11' ]
# Out:
#            date venue       team_name        opponent  poss_rolling  \
# 0    2017-08-11  Home         Arsenal  Leicester City           NaN
# 1787 2017-08-11  Away  Leicester City         Arsenal           NaN
#
#       gf_rolling  ga_rolling  sh_rolling  sot_rolling  fk_rolling  ...  opp  \
# 0            NaN         NaN         NaN          NaN         NaN  ...   13
# 1787         NaN         NaN         NaN          NaN         NaN  ...    0
#
#       team  opponent_poss_rolling  opponent_gf_rolling  opponent_ga_rolling  \
# 0        0                    NaN                  NaN                  NaN
# 1787    13                    NaN                  NaN                  NaN
#
#       opponent_sh_rolling  opponent_sot_rolling  opponent_fk_rolling  \
# 0                     NaN                   NaN                  NaN
# 1787                  NaN                   NaN                  NaN
#
#       opponent_pk_rolling  opponent_pkatt_rolling
# ...

# %%
df_trial.isnull().sum()
# Out:
# date                        0
# venue                       0
# team_name                   0
# opponent                    0
# poss_rolling              145
# gf_rolling                145
# ga_rolling                145
# sh_rolling                145
# sot_rolling               145
# fk_rolling                147
# pk_rolling                145
# pkatt_rolling             145
# result                      0
# local                       0
# opp                         0
# team                        0
# opponent_poss_rolling     145
# opponent_gf_rolling       145
# opponent_ga_rolling       145
# opponent_sh_rolling       145
# opponent_sot_rolling      145
# opponent_fk_rolling       147
# opponent_pk_rolling       145
# opponent_pkatt_rolling    145
# dtype: int64

# %%
df_trial[df_trial['date'] > '2022-05-22']
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 190  2022-08-05  Away   Arsenal   Crystal Palace          54.6         1.8
# 191  2022-08-13  Home   Arsenal   Leicester City          54.4         1.8
# 192  2022-08-20  Away   Arsenal      Bournemouth          51.6         2.2
# 193  2022-08-27  Home   Arsenal           Fulham          54.8         2.8
# 194  2022-08-31  Home   Arsenal      Aston Villa          59.4         3.2
# ...         ...   ...       ...              ...           ...         ...
# 4027 2022-10-01  Away    Wolves         West Ham          48.6         0.4
# 4028 2022-10-08  Away    Wolves          Chelsea          51.0         0.4
# 4029 2022-10-15  Home    Wolves  Nott'ham Forest          52.0         0.2
# 4030 2022-10-18  Away    Wolves   Crystal Palace          50.6         0.4
# 4031 2022-10-22  Home    Wolves   Leicester City          50.2         0.4
#
# ...

# %%
df_finall = df_trial.dropna()

# %%
df_final = pd.concat([df_finall,df_trial[df_trial['team_name'] == "Nott'ham Forest"]])

# %%
df_final[df_final['opponent_poss_rolling'].isnull()]
# Out:
# Empty DataFrame
# Columns: [date, venue, team_name, opponent, poss_rolling, gf_rolling, ga_rolling, sh_rolling, sot_rolling, fk_rolling, pk_rolling, pkatt_rolling, result, local, opp, team, opponent_poss_rolling, opponent_gf_rolling, opponent_ga_rolling, opponent_sh_rolling, opponent_sot_rolling, opponent_fk_rolling, opponent_pk_rolling, opponent_pkatt_rolling]
# Index: []
#
# [0 rows x 24 columns]

# %%
df_final[df_final['team_name'] == 'Brentford']
# Out:
#           date venue  team_name         opponent  poss_rolling  gf_rolling  \
# 458 2021-09-25  Home  Brentford        Liverpool          42.2         1.0
# 459 2021-10-03  Away  Brentford         West Ham          42.2         1.2
# 460 2021-10-16  Home  Brentford          Chelsea          41.2         1.6
# 461 2021-10-24  Home  Brentford   Leicester City          39.6         1.4
# 462 2021-10-30  Away  Brentford          Burnley          42.4         1.6
# 463 2021-11-06  Home  Brentford     Norwich City          46.4         1.4
# 464 2021-11-20  Away  Brentford    Newcastle Utd          52.4         1.0
# 465 2021-11-28  Home  Brentford          Everton          53.6         1.2
# 466 2021-12-02  Away  Brentford        Tottenham          52.6         1.4
# 467 2021-12-05  Away  Brentford     Leeds United          52.2         1.2
# 468 2021-12-10  Home  Brentford          Watford          48.0         1.4
# ...

# %%
df_trial
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 0    2017-08-11  Home   Arsenal   Leicester City           NaN         NaN
# 1    2017-08-19  Away   Arsenal       Stoke City           NaN         NaN
# 2    2017-08-27  Away   Arsenal        Liverpool           NaN         NaN
# 3    2017-09-09  Home   Arsenal      Bournemouth           NaN         NaN
# 4    2017-09-17  Away   Arsenal          Chelsea           NaN         NaN
# ...         ...   ...       ...              ...           ...         ...
# 4027 2022-10-01  Away    Wolves         West Ham          48.6         0.4
# 4028 2022-10-08  Away    Wolves          Chelsea          51.0         0.4
# 4029 2022-10-15  Home    Wolves  Nott'ham Forest          52.0         0.2
# 4030 2022-10-18  Away    Wolves   Crystal Palace          50.6         0.4
# 4031 2022-10-22  Home    Wolves   Leicester City          50.2         0.4
#
# ...

# %%
df_final
# Out:
#            date venue        team_name        opponent  poss_rolling  \
# 5    2017-09-25  Home          Arsenal       West Brom          60.4
# 6    2017-10-01  Home          Arsenal        Brighton          60.4
# 7    2017-10-14  Away          Arsenal         Watford          57.8
# 8    2017-10-22  Away          Arsenal         Everton          58.4
# 9    2017-10-28  Home          Arsenal    Swansea City          60.2
# ...         ...   ...              ...             ...           ...
# 2877 2022-10-03  Away  Nott'ham Forest  Leicester City          45.0
# 2878 2022-10-10  Home  Nott'ham Forest     Aston Villa          44.2
# 2879 2022-10-15  Away  Nott'ham Forest          Wolves          41.2
# 2880 2022-10-18  Away  Nott'ham Forest        Brighton          44.4
# 2881 2022-10-22  Home  Nott'ham Forest       Liverpool          40.2
#
#       gf_rolling  ga_rolling  sh_rolling  sot_rolling  fk_rolling  ...  opp  \
# ...

# %%
df_final[(df_final['team_name'] != "Nott'ham Forest") & (df_final['opp'] != "Nott'ham Forest")].isnull().sum()
# Out:
# date                      0
# venue                     0
# team_name                 0
# opponent                  0
# poss_rolling              0
# gf_rolling                0
# ga_rolling                0
# sh_rolling                0
# sot_rolling               0
# fk_rolling                0
# pk_rolling                0
# pkatt_rolling             0
# result                    0
# local                     0
# opp                       0
# team                      0
# opponent_poss_rolling     0
# opponent_gf_rolling       0
# opponent_ga_rolling       0
# opponent_sh_rolling       0
# opponent_sot_rolling      0
# opponent_fk_rolling       0
# opponent_pk_rolling       0
# opponent_pkatt_rolling    0
# dtype: int64

# %%
df_trial[df_trial['team_name'] == 'Fulham']
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 1536 2018-08-11  Home    Fulham   Crystal Palace           NaN         NaN
# 1537 2018-08-18  Away    Fulham        Tottenham           NaN         NaN
# 1538 2018-08-26  Home    Fulham          Burnley           NaN         NaN
# 1539 2018-09-01  Away    Fulham         Brighton           NaN         NaN
# 1540 2018-09-15  Away    Fulham  Manchester City           NaN         NaN
# ...         ...   ...       ...              ...           ...         ...
# 1619 2022-10-01  Home    Fulham    Newcastle Utd          43.8         2.0
# 1620 2022-10-09  Away    Fulham         West Ham          41.6         1.6
# 1621 2022-10-15  Home    Fulham      Bournemouth          45.6         1.6
# 1622 2022-10-20  Home    Fulham      Aston Villa          51.4         1.6
# 1623 2022-10-22  Away    Fulham     Leeds United          54.0         2.0
#
# ...

# %%
df_final[df_final['date'] > '2022-05-22']
# Out:
#            date venue        team_name        opponent  poss_rolling  \
# 190  2022-08-05  Away          Arsenal  Crystal Palace          54.6
# 191  2022-08-13  Home          Arsenal  Leicester City          54.4
# 192  2022-08-20  Away          Arsenal     Bournemouth          51.6
# 193  2022-08-27  Home          Arsenal          Fulham          54.8
# 194  2022-08-31  Home          Arsenal     Aston Villa          59.4
# ...         ...   ...              ...             ...           ...
# 2877 2022-10-03  Away  Nott'ham Forest  Leicester City          45.0
# 2878 2022-10-10  Home  Nott'ham Forest     Aston Villa          44.2
# 2879 2022-10-15  Away  Nott'ham Forest          Wolves          41.2
# 2880 2022-10-18  Away  Nott'ham Forest        Brighton          44.4
# 2881 2022-10-22  Home  Nott'ham Forest       Liverpool          40.2
#
#       gf_rolling  ga_rolling  sh_rolling  sot_rolling  fk_rolling  ...  opp  \
# ...

# %%
df_final[df_final['team_name'] == 'Liverpool']
# Out:
#            date venue  team_name         opponent  poss_rolling  gf_rolling  \
# 1994 2017-09-23  Away  Liverpool   Leicester City          56.2         1.8
# 1995 2017-10-01  Away  Liverpool    Newcastle Utd          56.2         1.8
# 1996 2017-10-14  Home  Liverpool   Manchester Utd          55.6         1.8
# 1997 2017-10-22  Away  Liverpool        Tottenham          58.2         1.0
# 1998 2017-10-28  Home  Liverpool     Huddersfield          63.8         1.2
# ...         ...   ...        ...              ...           ...         ...
# 2185 2022-10-01  Home  Liverpool         Brighton          68.4         2.6
# 2186 2022-10-09  Away  Liverpool          Arsenal          65.0         3.0
# 2187 2022-10-16  Home  Liverpool  Manchester City          62.4         3.2
# 2188 2022-10-19  Home  Liverpool         West Ham          56.0         1.6
# 2189 2022-10-22  Away  Liverpool  Nott'ham Forest          52.6         1.4
#
# ...

# %%
df_final
# Out:
#            date venue        team_name        opponent  poss_rolling  \
# 5    2017-09-25  Home          Arsenal       West Brom          60.4
# 6    2017-10-01  Home          Arsenal        Brighton          60.4
# 7    2017-10-14  Away          Arsenal         Watford          57.8
# 8    2017-10-22  Away          Arsenal         Everton          58.4
# 9    2017-10-28  Home          Arsenal    Swansea City          60.2
# ...         ...   ...              ...             ...           ...
# 2877 2022-10-03  Away  Nott'ham Forest  Leicester City          45.0
# 2878 2022-10-10  Home  Nott'ham Forest     Aston Villa          44.2
# 2879 2022-10-15  Away  Nott'ham Forest          Wolves          41.2
# 2880 2022-10-18  Away  Nott'ham Forest        Brighton          44.4
# 2881 2022-10-22  Home  Nott'ham Forest       Liverpool          40.2
#
#       gf_rolling  ga_rolling  sh_rolling  sot_rolling  fk_rolling  ...  opp  \
# ...

# %%
opponent_stats(opp_cols,new_cols)

# %%
df_final[new_cols].iloc[3257]
# Out:
# poss_rolling     45.6
# gf_rolling        1.6
# ga_rolling        0.6
# sh_rolling        9.6
# sot_rolling       3.2
# fk_rolling        0.0
# pk_rolling        0.0
# pkatt_rolling     0.0
# Name: 3423, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rand = RandomForestClassifier(random_state=505)

# %%
train = df_final[df_finalml['date'] < '2021-01-26']
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\415797449.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   train = df_final[df_finalml['date'] < '2021-01-26']

# %%
train
# Out:
#            date venue team_name        opponent  poss_rolling  gf_rolling  \
# 5    2017-09-25  Home   Arsenal       West Brom          60.4         1.4
# 6    2017-10-01  Home   Arsenal        Brighton          60.4         1.0
# 7    2017-10-14  Away   Arsenal         Watford          57.8         1.4
# 8    2017-10-22  Away   Arsenal         Everton          58.4         1.6
# 9    2017-10-28  Home   Arsenal    Swansea City          60.2         2.0
# ...         ...   ...       ...             ...           ...         ...
# 3958 2020-12-27  Home    Wolves       Tottenham          48.4         1.0
# 3959 2020-12-29  Away    Wolves  Manchester Utd          50.6         0.8
# 3960 2021-01-02  Away    Wolves        Brighton          51.2         0.8
# 3961 2021-01-12  Home    Wolves         Everton          50.4         1.4
# 3962 2021-01-16  Home    Wolves       West Brom          51.8         1.2
#
#       ga_rolling  sh_rolling  sot_rolling  fk_rolling  ...  opp  team  \
# ...

# %%
test = df_final[df_finalml['date'] >= '2021-01-26' ]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\1479824019.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test = df_final[df_finalml['date'] >= '2021-01-26' ]

# %%
test[test['team_name'] == 'Fulham']
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 1592 2021-01-27  Away    Fulham         Brighton          43.2         0.6
# 1593 2021-01-30  Away    Fulham        West Brom          43.0         0.4
# 1594 2021-02-03  Home    Fulham   Leicester City          46.0         0.8
# 1595 2021-02-06  Home    Fulham         West Ham          48.0         0.6
# 1596 2021-02-14  Away    Fulham          Everton          53.6         0.6
# 1597 2021-02-17  Away    Fulham          Burnley          56.0         0.8
# 1598 2021-02-20  Home    Fulham    Sheffield Utd          56.2         1.0
# 1599 2021-02-28  Away    Fulham   Crystal Palace          56.4         0.8
# 1600 2021-03-04  Home    Fulham        Tottenham          56.6         0.8
# 1601 2021-03-07  Away    Fulham        Liverpool          56.4         0.8
# 1602 2021-03-13  Home    Fulham  Manchester City          53.6         0.6
# ...

# %%
newtest = test[test['date'] < '2021-10-24']

# %%
len(newtest)
# Out:
# 554

# %%
holdout_test = test[(test['date'] >= '2021-10-24') & (test['date'] < '2022-08-05') & (test['team_name'] != "Nott'ham Forest") ]

# %%
test2022 = test[(test['date'] >= '2022-08-05') & (test['date'] < '2022-10-22')]

# %%
pred2022 = test[test['date'] >= '2022-10-22']

# %%
test[test['team_name'] == 'Fulham']
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 1592 2021-01-27  Away    Fulham         Brighton          43.2         0.6
# 1593 2021-01-30  Away    Fulham        West Brom          43.0         0.4
# 1594 2021-02-03  Home    Fulham   Leicester City          46.0         0.8
# 1595 2021-02-06  Home    Fulham         West Ham          48.0         0.6
# 1596 2021-02-14  Away    Fulham          Everton          53.6         0.6
# 1597 2021-02-17  Away    Fulham          Burnley          56.0         0.8
# 1598 2021-02-20  Home    Fulham    Sheffield Utd          56.2         1.0
# 1599 2021-02-28  Away    Fulham   Crystal Palace          56.4         0.8
# 1600 2021-03-04  Home    Fulham        Tottenham          56.6         0.8
# 1601 2021-03-07  Away    Fulham        Liverpool          56.4         0.8
# 1602 2021-03-13  Home    Fulham  Manchester City          53.6         0.6
# ...

# %%
train
# Out:
#            date venue team_name        opponent  poss_rolling  gf_rolling  \
# 5    2017-09-25  Home   Arsenal       West Brom          60.4         1.4
# 6    2017-10-01  Home   Arsenal        Brighton          60.4         1.0
# 7    2017-10-14  Away   Arsenal         Watford          57.8         1.4
# 8    2017-10-22  Away   Arsenal         Everton          58.4         1.6
# 9    2017-10-28  Home   Arsenal    Swansea City          60.2         2.0
# ...         ...   ...       ...             ...           ...         ...
# 3958 2020-12-27  Home    Wolves       Tottenham          48.4         1.0
# 3959 2020-12-29  Away    Wolves  Manchester Utd          50.6         0.8
# 3960 2021-01-02  Away    Wolves        Brighton          51.2         0.8
# 3961 2021-01-12  Home    Wolves         Everton          50.4         1.4
# 3962 2021-01-16  Home    Wolves       West Brom          51.8         1.2
#
#       ga_rolling  sh_rolling  sot_rolling  fk_rolling  ...  opp  team  \
# ...

# %%
newtest
# Out:
#            date venue team_name        opponent  poss_rolling  gf_rolling  \
# 133  2021-01-26  Away   Arsenal     Southampton          57.0         2.2
# 134  2021-01-30  Home   Arsenal  Manchester Utd          57.4         2.2
# 135  2021-02-02  Away   Arsenal          Wolves          56.0         2.0
# 136  2021-02-06  Away   Arsenal     Aston Villa          52.8         1.4
# 137  2021-02-14  Home   Arsenal    Leeds United          52.4         1.4
# ...         ...   ...       ...             ...           ...         ...
# 3985 2021-09-11  Away    Wolves         Watford          51.8         0.2
# 3987 2021-09-26  Away    Wolves     Southampton          52.4         0.4
# 3988 2021-10-02  Home    Wolves   Newcastle Utd          52.2         0.6
# 3989 2021-10-16  Away    Wolves     Aston Villa          51.2         1.0
# 3990 2021-10-23  Away    Wolves    Leeds United          52.8         1.6
#
#       ga_rolling  sh_rolling  sot_rolling  fk_rolling  ...  opp  team  \
# ...

# %%
holdout_test
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 161  2021-10-30  Away   Arsenal   Leicester City          50.0         1.8
# 162  2021-11-07  Home   Arsenal          Watford          46.4         2.0
# 163  2021-11-20  Away   Arsenal        Liverpool          49.2         1.6
# 164  2021-11-27  Home   Arsenal    Newcastle Utd          48.4         1.6
# 165  2021-12-02  Away   Arsenal   Manchester Utd          50.4         1.6
# ...         ...   ...       ...              ...           ...         ...
# 4015 2022-04-30  Home    Wolves         Brighton          55.6         1.0
# 4016 2022-05-07  Away    Wolves          Chelsea          53.2         0.8
# 4017 2022-05-11  Home    Wolves  Manchester City          52.0         0.8
# 4018 2022-05-15  Home    Wolves     Norwich City          48.8         0.6
# 4019 2022-05-22  Away    Wolves        Liverpool          49.8         0.8
#
# ...

# %%
from sklearn.metrics import plot_confusion_matrix,classification_report,accuracy_score

# %%
n_estimators=[100,128,135,145,200]
max_features= ['log2','sqrt']
bootstrap = [True,False]
oob_score = [True,False]
min_samples_split = [2,5,10,20,30]
min_samples_leaf = [1, 2, 4]

# %%
param_grid = {'n_estimators':n_estimators,
             'max_features':max_features,
             'bootstrap':bootstrap,
             'oob_score':oob_score,
             'min_samples_split':min_samples_split,
             'min_samples_leaf': min_samples_leaf }

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(rand,param_grid,scoring='accuracy')

# %%
train.columns
# Out:
# Index(['date', 'venue', 'team_name', 'opponent', 'poss_rolling', 'gf_rolling',
#        'ga_rolling', 'sh_rolling', 'sot_rolling', 'fk_rolling', 'pk_rolling',
#        'pkatt_rolling', 'result', 'local', 'opp', 'team',
#        'opponent_poss_rolling', 'opponent_gf_rolling', 'opponent_ga_rolling',
#        'opponent_sh_rolling', 'opponent_sot_rolling', 'opponent_fk_rolling',
#        'opponent_pk_rolling', 'opponent_pkatt_rolling'],
#       dtype='object')

# %%
param = ['local','opp','team','poss_rolling', 'gf_rolling',
       'ga_rolling', 'sh_rolling', 'sot_rolling', 'fk_rolling', 'pk_rolling',
       'pkatt_rolling','opponent_poss_rolling', 'opponent_gf_rolling', 'opponent_ga_rolling',
       'opponent_sh_rolling', 'opponent_sot_rolling', 'opponent_fk_rolling',
       'opponent_pk_rolling', 'opponent_pkatt_rolling']

# %%
grid.fit(train[param], train['result'])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 750 fits failed out of a total of 3000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 750 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\USER\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 437, in fit
#     raise ValueError("Out of bag estimation only available if bootstrap=True")
# ValueError: Out of bag estimation only available if bootstrap=True
#
# ...

# %%
grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'log2',
#  'min_samples_leaf': 2,
#  'min_samples_split': 30,
#  'n_estimators': 128,
#  'oob_score': True}

# %%
pred = grid.predict(newtest[param])

# %%
print(classification_report(newtest['result'],pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.63      0.54       214
#            1       0.49      0.61      0.54       214
#            2       0.25      0.02      0.03       126
#
#     accuracy                           0.48       554
#    macro avg       0.41      0.42      0.37       554
# weighted avg       0.43      0.48      0.43       554

# %%
plot_confusion_matrix(grid,newtest[param],newtest['result'])

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()

# %%
xgb.fit(train[param],train['result'])
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...)

# %%
preds = xgb.predict(newtest[param])

# %%
print(classification_report(newtest['result'],preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.55      0.50       214
#            1       0.47      0.54      0.50       214
#            2       0.25      0.10      0.15       126
#
#     accuracy                           0.44       554
#    macro avg       0.39      0.40      0.38       554
# weighted avg       0.41      0.44      0.42       554

# %%
plot_confusion_matrix(xgb,newtest[param],newtest['result'])

# %%
parameters = { 'learning_rate' : [0.1],
               'n_estimators' : [40],
               'max_depth': [3],
               'min_child_weight': [3],
               'gamma':[0.4],
               'subsample' : [0.8]}

# %%
grid_xgb = GridSearchCV(xgb, param_grid = parameters, scoring = 'accuracy')

# %%
grid_xgb.fit(train[param],train['result'])
# Out:
# GridSearchCV(estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      callbacks=None, colsample_bylevel=1,
#                                      colsample_bynode=1, colsample_bytree=1,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=0, gpu_id=-1,
#                                      grow_policy='depthwise',
#                                      importance_type=None,
#                                      interaction_constraints='',
#                                      learning_rate=0.300000012, max_bin=256,
#                                      max_cat_to_...,
#                                      max_depth=6, max_leaves=0,
#                                      min_child_weight=1, missing=nan,
#                                      monotone_constraints='()',
# ...

# %%
xgp_preds = grid_xgb.predict(holdout_test[param])
grid_preds = grid.predict(holdout_test[param])

# %%
print(classification_report(holdout_test['result'],xgp_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.66      0.58       230
#            1       0.52      0.66      0.58       230
#            2       0.40      0.02      0.03       126
#
#     accuracy                           0.52       586
#    macro avg       0.48      0.44      0.40       586
# weighted avg       0.50      0.52      0.46       586

# %%
print(classification_report(holdout_test['result'],grid_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.67      0.58       230
#            1       0.53      0.65      0.58       230
#            2       0.29      0.02      0.03       126
#
#     accuracy                           0.52       586
#    macro avg       0.44      0.44      0.40       586
# weighted avg       0.47      0.52      0.46       586

# %%
plot_confusion_matrix(grid_xgb,holdout_test[param],holdout_test['result'])

# %%
plot_confusion_matrix(grid,holdout_test[param],holdout_test['result'])

# %%
holdout_test['predicted'] = grid_preds
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\602505808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   holdout_test['predicted'] = grid_preds

# %%
res = holdout_test.copy()

# %%
holdout_test[holdout_test['team_name'] == 'Manchester City']
# Out:
#            date venue        team_name        opponent  poss_rolling  \
# 2351 2021-10-30  Home  Manchester City  Crystal Palace          59.0
# 2352 2021-11-06  Away  Manchester City  Manchester Utd          60.0
# 2353 2021-11-21  Home  Manchester City         Everton          61.4
# 2354 2021-11-28  Home  Manchester City        West Ham          66.4
# 2355 2021-12-01  Away  Manchester City     Aston Villa          66.0
# 2356 2021-12-04  Away  Manchester City         Watford          68.4
# 2357 2021-12-11  Home  Manchester City          Wolves          70.0
# 2358 2021-12-14  Home  Manchester City    Leeds United          70.8
# 2359 2021-12-19  Away  Manchester City   Newcastle Utd          68.4
# 2360 2021-12-26  Home  Manchester City  Leicester City          69.2
# 2361 2021-12-29  Away  Manchester City       Brentford          70.8
# 2362 2022-01-01  Away  Manchester City         Arsenal          70.8
# 2363 2022-01-15  Home  Manchester City         Chelsea          70.6
# ...

# %%
holdout_test[holdout_test['team_name'] == 'Wolves']
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 3991 2021-11-01  Home    Wolves          Everton          49.0         1.4
# 3992 2021-11-06  Away    Wolves   Crystal Palace          49.0         1.8
# 3993 2021-11-20  Home    Wolves         West Ham          48.6         1.6
# 3994 2021-11-27  Away    Wolves     Norwich City          48.8         1.4
# 3995 2021-12-01  Home    Wolves          Burnley          49.6         0.8
# 3996 2021-12-04  Home    Wolves        Liverpool          55.2         0.6
# 3997 2021-12-11  Away    Wolves  Manchester City          49.8         0.2
# 3998 2021-12-15  Away    Wolves         Brighton          47.6         0.2
# 3999 2021-12-19  Home    Wolves          Chelsea          45.2         0.2
# 4000 2022-01-03  Away    Wolves   Manchester Utd          41.4         0.2
# 4001 2022-01-15  Home    Wolves      Southampton          38.2         0.4
# ...

# %%
holdout_test1 = holdout_test.copy()

# %%
holdout_test1['trial'] = np.where(holdout_test['result']== holdout_test['predicted'], 'right', 'wrong')

# %%
holdout_testmc = holdout_test1[holdout_test1['team_name'] == 'Tottenham']

# %%
res = holdout_test1.copy()

# %%
res = res[['date', 'venue', 'team_name', 'opponent','result', 'predicted', 'trial', 'poss_rolling', 'gf_rolling',
       'ga_rolling', 'sh_rolling', 'sot_rolling', 'fk_rolling', 'pk_rolling',
       'pkatt_rolling', 'local', 'opp', 'team',
       'opponent_poss_rolling', 'opponent_gf_rolling', 'opponent_ga_rolling',
       'opponent_sh_rolling', 'opponent_sot_rolling', 'opponent_fk_rolling',
       'opponent_pk_rolling', 'opponent_pkatt_rolling']]

# %%
res_per = res[res['team_name'] == 'Brentford']

# %%
res_per['trial'].value_counts()
# Out:
# right    18
# wrong    12
# Name: trial, dtype: int64

# %%
#City 79 %
#Arsenal 62%
#Liverpool 73%
#Chelsea 55%
#Man Utd 56 %
#Tottenham 50 %

# %%
test.dropna()
# Out:
#            date venue        team_name        opponent  poss_rolling  \
# 133  2021-01-26  Away          Arsenal     Southampton          57.0
# 134  2021-01-30  Home          Arsenal  Manchester Utd          57.4
# 135  2021-02-02  Away          Arsenal          Wolves          56.0
# 136  2021-02-06  Away          Arsenal     Aston Villa          52.8
# 137  2021-02-14  Home          Arsenal    Leeds United          52.4
# ...         ...   ...              ...             ...           ...
# 2877 2022-10-03  Away  Nott'ham Forest  Leicester City          45.0
# 2878 2022-10-10  Home  Nott'ham Forest     Aston Villa          44.2
# 2879 2022-10-15  Away  Nott'ham Forest          Wolves          41.2
# 2880 2022-10-18  Away  Nott'ham Forest        Brighton          44.4
# 2881 2022-10-22  Home  Nott'ham Forest       Liverpool          40.2
#
#       gf_rolling  ga_rolling  sh_rolling  sot_rolling  fk_rolling  ...  opp  \
# ...

# %%
test.isnull().sum()
# Out:
# date                      0
# venue                     0
# team_name                 0
# opponent                  0
# poss_rolling              5
# gf_rolling                5
# ga_rolling                5
# sh_rolling                5
# sot_rolling               5
# fk_rolling                5
# pk_rolling                5
# pkatt_rolling             5
# result                    0
# local                     0
# opp                       0
# team                      0
# opponent_poss_rolling     0
# opponent_gf_rolling       0
# opponent_ga_rolling       0
# opponent_sh_rolling       0
# opponent_sot_rolling      0
# opponent_fk_rolling       0
# opponent_pk_rolling       0
# opponent_pkatt_rolling    0
# dtype: int64

# %%
#errors = []
#misclassifications = []

#for n in range(1,200):
    #rfc = RandomForestClassifier(n_estimators=n, random_state=505, bootstrap= True, max_features= 'log2',min_samples_leaf = 2,min_samples_split= 30,oob_score= True)
    #rfc.fit(train[param],train['result'])
    #predss = rfc.predict(test[param])
    #err = 1 - accuracy_score(predss,test['result'])
    #n_missed = np.sum(preds != test['result']) # watch the video to understand this line!!
    #errors.append(err)
    #misclassifications.append(n_missed)

# %%
#plt.plot(range(1,200),errors)

# %%
#plt.plot(range(1,200),misclassifications)

# %%
df_finalml
# Out:
#            date venue team_name         opponent  poss_rolling  gf_rolling  \
# 0    2017-08-11  Home   Arsenal   Leicester City           NaN         NaN
# 1    2017-08-19  Away   Arsenal       Stoke City           NaN         NaN
# 2    2017-08-27  Away   Arsenal        Liverpool           NaN         NaN
# 3    2017-09-09  Home   Arsenal      Bournemouth           NaN         NaN
# 4    2017-09-17  Away   Arsenal          Chelsea           NaN         NaN
# ...         ...   ...       ...              ...           ...         ...
# 4027 2022-10-01  Away    Wolves         West Ham          48.6         0.4
# 4028 2022-10-08  Away    Wolves          Chelsea          51.0         0.4
# 4029 2022-10-15  Home    Wolves  Nott'ham Forest          52.0         0.2
# 4030 2022-10-18  Away    Wolves   Crystal Palace          50.6         0.4
# 4031 2022-10-22  Home    Wolves   Leicester City          50.2         0.4
#
#       ga_rolling  sh_rolling  sot_rolling  fk_rolling  pk_rolling  \
# ...

# %%
final_model = RandomForestClassifier(bootstrap= True,max_features= 'log2',min_samples_leaf= 1,min_samples_split= 30,n_estimators= 128,oob_score= True, random_state=505)

# %%
final_train = pd.concat([train,newtest])

# %%
final_model.fit(final_train[param],final_train['result'])
# Out:
# RandomForestClassifier(max_features='log2', min_samples_split=30,
#                        n_estimators=128, oob_score=True, random_state=505)

# %%
final_model.feature_importances_
# Out:
# array([0.02054877, 0.05656835, 0.06020649, 0.1179565 , 0.05060659,
#        0.04424049, 0.08900819, 0.07769282, 0.03129088, 0.01050136,
#        0.01324208, 0.12233598, 0.04780514, 0.04743285, 0.08095158,
#        0.07631723, 0.03051483, 0.00882686, 0.01395303])

# %%
final_train.columns
# Out:
# Index(['date', 'venue', 'team_name', 'opponent', 'poss_rolling', 'gf_rolling',
#        'ga_rolling', 'sh_rolling', 'sot_rolling', 'fk_rolling', 'pk_rolling',
#        'pkatt_rolling', 'result', 'local', 'opp', 'team',
#        'opponent_poss_rolling', 'opponent_gf_rolling', 'opponent_ga_rolling',
#        'opponent_sh_rolling', 'opponent_sot_rolling', 'opponent_fk_rolling',
#        'opponent_pk_rolling', 'opponent_pkatt_rolling'],
#       dtype='object')

# %%
feat_imp = pd.DataFrame(index=param,data = final_model.feature_importances_, columns = ['importance'] )

# %%
feat_imp.sort_values('importance',ascending=False)
# Out:
#                         importance
# opponent_poss_rolling     0.122336
# poss_rolling              0.117956
# sh_rolling                0.089008
# opponent_sh_rolling       0.080952
# sot_rolling               0.077693
# opponent_sot_rolling      0.076317
# team                      0.060206
# opp                       0.056568
# gf_rolling                0.050607
# opponent_gf_rolling       0.047805
# opponent_ga_rolling       0.047433
# ga_rolling                0.044240
# fk_rolling                0.031291
# opponent_fk_rolling       0.030515
# local                     0.020549
# opponent_pkatt_rolling    0.013953
# pkatt_rolling             0.013242
# pk_rolling                0.010501
# opponent_pk_rolling       0.008827

# %%
holdout_test.isnull().sum()
# Out:
# date                      0
# venue                     0
# team_name                 0
# opponent                  0
# poss_rolling              0
# gf_rolling                0
# ga_rolling                0
# sh_rolling                0
# sot_rolling               0
# fk_rolling                0
# pk_rolling                0
# pkatt_rolling             0
# result                    0
# local                     0
# opp                       0
# team                      0
# opponent_poss_rolling     0
# opponent_gf_rolling       0
# opponent_ga_rolling       0
# opponent_sh_rolling       0
# opponent_sot_rolling      0
# opponent_fk_rolling       0
# opponent_pk_rolling       0
# opponent_pkatt_rolling    0
# predicted                 0
# dtype: int64

# %%
pred = final_model.predict(holdout_test[param])

# %%
print(classification_report(holdout_test['result'],pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.66      0.58       230
#            1       0.54      0.65      0.59       230
#            2       0.53      0.08      0.14       126
#
#     accuracy                           0.53       586
#    macro avg       0.53      0.46      0.44       586
# weighted avg       0.53      0.53      0.49       586

# %%
plot_confusion_matrix(final_model,holdout_test[param],holdout_test['result'])

# %%
df_finalfit = pd.concat([train,test[test['date'] < '2022-08-05']])

# %%
df_finalfit = df_finalfit.dropna()

# %%
param
# Out:
# ['local',
#  'opp',
#  'team',
#  'poss_rolling',
#  'gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling',
#  'opponent_poss_rolling',
#  'opponent_gf_rolling',
#  'opponent_ga_rolling',
#  'opponent_sh_rolling',
#  'opponent_sot_rolling',
#  'opponent_fk_rolling',
#  'opponent_pk_rolling',
#  'opponent_pkatt_rolling']

# %%
final_model.fit(df_finalfit[param],df_finalfit['result'])
# Out:
# RandomForestClassifier(max_features='log2', min_samples_split=30,
#                        n_estimators=128, oob_score=True, random_state=505)

# %%
test_2022 = test2022.dropna()

# %%
preds_2022 = final_model.predict(test_2022[param])

# %%
prob_test = final_model.predict_proba(test_2022[param])

# %%
test_2022['predicted'] = preds_2022
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\674131243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_2022['predicted'] = preds_2022

# %%
test_2022[['win','lose','draw']] = prob_test*100
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\2115724080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_2022[['win','lose','draw']] = prob_test*100
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\2115724080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_2022[['win','lose','draw']] = prob_test*100
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\2115724080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
test_2022.columns
# Out:
# Index(['date', 'venue', 'team_name', 'opponent', 'poss_rolling', 'gf_rolling',
#        'ga_rolling', 'sh_rolling', 'sot_rolling', 'fk_rolling', 'pk_rolling',
#        'pkatt_rolling', 'result', 'local', 'opp', 'team',
#        'opponent_poss_rolling', 'opponent_gf_rolling', 'opponent_ga_rolling',
#        'opponent_sh_rolling', 'opponent_sot_rolling', 'opponent_fk_rolling',
#        'opponent_pk_rolling', 'opponent_pkatt_rolling', 'predicted', 'win',
#        'lose', 'draw'],
#       dtype='object')

# %%
test_2022['correct'] = np.where(test_2022['result'] == test_2022['predicted'], 'right', 'wrong')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14508\836934085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_2022['correct'] = np.where(test_2022['result'] == test_2022['predicted'], 'right', 'wrong')

# %%
testing = test_2022[['date', 'venue', 'team_name', 'opponent','local','win','lose','draw','predicted','result','correct']]

# %%
testing[testing['team_name'] == 'Southampton']
# Out:
#            date venue    team_name         opponent  local        win  \
# 3148 2022-08-06  Away  Southampton        Tottenham      0  19.853783
# 3149 2022-08-13  Home  Southampton     Leeds United      1  31.607573
# 3150 2022-08-20  Away  Southampton   Leicester City      0  27.644692
# 3151 2022-08-27  Home  Southampton   Manchester Utd      1  34.039502
# 3152 2022-08-30  Home  Southampton          Chelsea      1  25.680145
# 3153 2022-09-03  Away  Southampton           Wolves      0  39.594150
# 3154 2022-09-16  Away  Southampton      Aston Villa      0  30.810131
# 3155 2022-10-01  Home  Southampton          Everton      1  37.633048
# 3156 2022-10-08  Away  Southampton  Manchester City      0   7.990497
# 3157 2022-10-16  Home  Southampton         West Ham      1  40.920183
# 3158 2022-10-19  Away  Southampton      Bournemouth      0  22.636144
#
#            lose       draw  predicted  result correct
# 3148  60.598685  19.547532          1       1   right
# ...

# %%
s = test_2022[test_2022['team_name'] == 'Brentford']

# %%
s['correct'].value_counts()
# Out:
# wrong    8
# right    3
# Name: correct, dtype: int64

# %%
print(classification_report(test_2022['result'],preds_2022))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.74      0.62        73
#            1       0.54      0.75      0.63        77
#            2       0.00      0.00      0.00        58
#
#     accuracy                           0.54       208
#    macro avg       0.36      0.50      0.42       208
# weighted avg       0.39      0.54      0.45       208
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
df_finalpred = pd.concat([train,test[test['date'] < '2022-10-22']])

# %%
df_finalpred = df_finalpred.dropna()

# %%
final_model.fit(df_finalpred[param],df_finalpred['result'])
# Out:
# RandomForestClassifier(max_features='log2', min_samples_split=30,
#                        n_estimators=128, oob_score=True, random_state=505)

# %%
pred2022 = pred2022.dropna()

# %%
predictions = final_model.predict(pred2022[param])

# %%
prob = final_model.predict_proba(pred2022[param])

# %%
pred2022['predicted'] = predictions

# %%
pred2022[['win','lose','draw']] = prob*100

# %%
g = pred2022[['date', 'venue', 'team_name', 'opponent','local','win','lose','draw','predicted']]

# %%
g
# Out:
#            date venue        team_name         opponent  local        win  \
# 200  2022-10-22  Away          Arsenal      Southampton      0  55.472090
# 326  2022-10-22  Home      Aston Villa        Brentford      1  42.418202
# 452  2022-10-22  Away      Bournemouth         West Ham      0  25.493661
# 502  2022-10-22  Away        Brentford      Aston Villa      0  27.548324
# 703  2022-10-22  Away         Brighton  Manchester City      0  22.954316
# 1132 2022-10-22  Home          Chelsea   Manchester Utd      1  43.202253
# 1333 2022-10-22  Away   Crystal Palace          Everton      0  31.997905
# 1535 2022-10-22  Home          Everton   Crystal Palace      1  38.233636
# 2189 2022-10-22  Away        Liverpool  Nott'ham Forest      0  55.365844
# 2390 2022-10-22  Home  Manchester City         Brighton      1  55.246557
# 2591 2022-10-22  Away   Manchester Utd          Chelsea      0  36.288702
# 2793 2022-10-22  Away    Newcastle Utd        Tottenham      0  59.269503
# ...
