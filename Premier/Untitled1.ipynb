# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import swifter

# %%
df = pd.read_csv('Base de Dados.csv', header=4, index_col=0)

# %%
df1 = df.dropna()

# %%
df.columns
# Out:
# Index(['Unnamed: 1', 'ID', 'ProductID', 'ClientID', 'Discount', 'UnitPrice',
#        'Quantity', 'StoreID', 'Date'],
#       dtype='object')

# %%
df2=df[['ID', 'ProductID', 'ClientID', 'Discount', 'UnitPrice',
       'Quantity', 'StoreID', 'Date']]

# %%
plt.plot(df_x['Date'],df_x['Quantity'])

# %%
df_iron = df2[df2['ProductID'] == '002d4ea7c04739c130bb74d7e7cd16943']

# %%
df_y = df_iron['Quantity']

# %%
df_iron
# Out:
#                                    ID                          ProductID  \
# NaN  85647e1ff3e4b10814f375af01c38836  002d4ea7c04739c130bb74d7e7cd16943
# NaN  ec451fb3a1ee5782fef4937473a9ffac  002d4ea7c04739c130bb74d7e7cd16943
# NaN  c68e47bd3dab5dd575a6c65848663923  002d4ea7c04739c130bb74d7e7cd16943
# NaN  a97c9b194a026ac3e75726c485f6e8ea  002d4ea7c04739c130bb74d7e7cd16943
# NaN  ea110ced6459b4dc6c73e0b2367077e9  002d4ea7c04739c130bb74d7e7cd16943
# ..                                ...                                ...
# NaN  ffdb12bf66b3d0145d09d962745a05f6  002d4ea7c04739c130bb74d7e7cd16943
# NaN  53802dd14f00658bd63315e41be39610  002d4ea7c04739c130bb74d7e7cd16943
# NaN  bb5a519e352b45b714192a02ffe25681  002d4ea7c04739c130bb74d7e7cd16943
# NaN  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# NaN  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
#
#      ClientID Discount UnitPrice  Quantity  StoreID        Date
# ...

# %%
df_x = df_iron[df_iron['Date'] >= '01-01-2019']

# %%
# Out:
#                                    ID                          ProductID  \
# NaN  85647e1ff3e4b10814f375af01c38836  002d4ea7c04739c130bb74d7e7cd16943
# NaN  ec451fb3a1ee5782fef4937473a9ffac  002d4ea7c04739c130bb74d7e7cd16943
# NaN  c68e47bd3dab5dd575a6c65848663923  002d4ea7c04739c130bb74d7e7cd16943
# NaN  a97c9b194a026ac3e75726c485f6e8ea  002d4ea7c04739c130bb74d7e7cd16943
# NaN  ea110ced6459b4dc6c73e0b2367077e9  002d4ea7c04739c130bb74d7e7cd16943
# ..                                ...                                ...
# NaN  ffdb12bf66b3d0145d09d962745a05f6  002d4ea7c04739c130bb74d7e7cd16943
# NaN  53802dd14f00658bd63315e41be39610  002d4ea7c04739c130bb74d7e7cd16943
# NaN  bb5a519e352b45b714192a02ffe25681  002d4ea7c04739c130bb74d7e7cd16943
# NaN  0d8ac7eb8e52447e022b8e4a30ff6394  002d4ea7c04739c130bb74d7e7cd16943
# NaN  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
#
#      ClientID Discount UnitPrice  Quantity  StoreID        Date
# ...
